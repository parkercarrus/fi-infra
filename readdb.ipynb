# %% [markdown]
# ### database

# %%
import duckdb
conn = duckdb.connect('algory.duckdb')
df = conn.sql(f"SELECT * FROM {"positions"}").df()
display(df)
conn.close()
# Out:
#    $Ticker  Entry Date Avg Cost # of Shares
# 0      MSFT    3/20/23  $276.42          26
# 1       JPM    3/13/23  $131.90          41
# 2      META    8/10/24  $459.61          12
# 3      NVDA    8/12/24  $115.53          35
# 4       SPY    6/30/25  $634.00          27
# 5      GOOG     9/2/25  $223.63          55
# 6       WWD     9/4/25  $244.94          15
# 7       SGI     9/4/25   $85.68          30
# 8        NE    9/15/25   $31.13          45
# 9       TDW    9/15/25   $59.52          25
# 10     HOOD   10/16/25  $131.32          25
# 11     TSLA   10/21/25  $448.76           5
# 12       RL   10/21/25  $337.77           5
# 13       NU   10/21/25   $15.38         200
# 14      PVH   10/21/25   $85.14          25
# 15      NVO   10/21/25   $56.11         115
# 16     BWXT   10/21/25  $205.50          15
# 17      GEV   10/21/25  $591.71          10
# 18     COIN   10/29/25  $356.28           5
# 19      CAT   10/29/25  $610.63          10
# ...
